# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/train.csv")
df["Target"] = (df["Heart Disease"] == "Presence") * 1
df = df.drop(["id", "Heart Disease"], axis=1)

print(df.info())
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Age                      630000 non-null  int64
#  1   Sex                      630000 non-null  int64
#  2   Chest pain type          630000 non-null  int64
#  3   BP                       630000 non-null  int64
#  4   Cholesterol              630000 non-null  int64
#  5   FBS over 120             630000 non-null  int64
#  6   EKG results              630000 non-null  int64
#  7   Max HR                   630000 non-null  int64
#  8   Exercise angina          630000 non-null  int64
#  9   ST depression            630000 non-null  float64
#  10  Slope of ST              630000 non-null  int64
#  11  Number of vessels fluro  630000 non-null  int64
#  12  Thallium                 630000 non-null  int64
#  13  Target                   630000 non-null  int64
# ...

# %%
CAT_COLS = ["Sex", "Chest pain type", "FBS over 120", "EKG results", "Exercise angina", "Slope of ST", "Number of vessels fluro", "Thallium"]
NUMERIC_COLS = ["Age", "ST depression", "BP", "Cholesterol", "Max HR"]
TARGET_COL = "Target"
for c in CAT_COLS:
    df[c] = df[c].astype("string")

for c in CAT_COLS:
    vc = df[c].value_counts().sort_index()
    plt.bar(vc.index, vc.values)
    plt.title(f"{c} - Value Counts")
    plt.xlabel(c)
    plt.ylabel("Count")
    plt.show()

for c in CAT_COLS:
    tr = df[[c, TARGET_COL]].groupby(c)[TARGET_COL].mean()
    plt.bar(tr.index, tr.values)
    plt.title(f"{c} - Target(=1) Rate")
    plt.xlabel(c)
    plt.ylabel("Target Rate ")
    plt.show()

for c in NUMERIC_COLS:
    plt.hist(df[c], bins=10)
    plt.title(f"{c} - Histogram")
    plt.xlabel(c)
    plt.ylabel("Frequency")
    plt.show()
    
c = TARGET_COL
vc = df[c].value_counts().sort_index()
plt.bar(vc.index, vc.values)
plt.title(f"{c} - Value Counts")
plt.xlabel(c)
plt.ylabel("Count")
plt.show()
